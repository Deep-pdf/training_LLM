# %%
import numpy as np

# %%
#creating a 1D array
arry =np.array([1,2,3,4,5])
print(arry)
print(arry.dtype)
# Out:
# [1 2 3 4 5]
# int64

# %%
#creating a 2D array
arry2=np.array([[1.5,2,3],[4,5.2,6],[7,8,9.1]])
print(arry2)
print(arry2.dtype)
# Out:
# [[1.5 2.  3. ]
#  [4.  5.2 6. ]
#  [7.  8.  9.1]]
# float64
